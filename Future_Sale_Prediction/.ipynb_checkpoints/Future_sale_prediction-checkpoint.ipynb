# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(df['TV'])
plt.show()

# %%
df.hist()
plt.show()

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1361d710850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1361da306d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1361cb669d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1361da31990>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1361d9e2150>,
# ...
#  'means': []}

# %%
plt.scatter(df['Sales'],df['TV'])

# %%
plt.scatter(df['Sales'],df['TV'],marker="*", color="black")
plt.scatter(df['Sales'],df['Radio'],marker="*", color="yellow")
plt.scatter(df['Sales'],df['Newspaper'],marker="*", color="green")

# %%
# The Sales of TV is particulray high as compared to Radio and Newspaper

# %%
correlation=df.corr()

# %%
print(correlation['Sales'])
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# Name: Sales, dtype: float64

# %%
# Future sale predict model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Before using training model, need x and y from dataframe
x=df.drop(['Sales'],axis=1)

# %%
y=df['Sales']

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
# Using Train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20,random_state=36)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c=lr.intercept_
c
# Out:
# 4.809282562188875

# %%
m=lr.coef_
m
# Out:
# array([ 0.05416504,  0.10316543, -0.00156319])

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.8997673779003685
